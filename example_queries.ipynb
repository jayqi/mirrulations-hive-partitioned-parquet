# %%
import duckdb
from dotenv import load_dotenv


load_dotenv()

conn = duckdb.connect()

# %%
# !du -sh mirrulations/bulk/raw-data/
# Out:
# 2.5G	mirrulations/bulk/raw-data/

# %%
# !du -sh parquet/
# Out:
# 424M	parquet/

# %% [markdown]
# ### Dockets

# %%
query = """\
SELECT *
FROM read_parquet(
  'parquet/dockets/agency_code=*/year=*/*.parquet',
  hive_partitioning = 1
)
LIMIT 10;
;
"""

conn.query(query)
# Out:
# ┌───────────────┬───────────────┬─────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────┬─────────┐
# │   docket_id   │  docket_type  │     modify_date     │                                                            title                                                            │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       raw_json                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ agency_code │  year   │
# │    varchar    │    varchar    │      timestamp      │                                                           varchar                                                           │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       varchar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │   varchar   │ varchar │
# ├───────────────┼───────────────┼─────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────┤
# │ CMS-2022-0001 │ Rulemaking    │ 2022-06-22 12:28:52 │ Securing Updated and Necessary Statutory Evaluations Timely; Proposal to Withdraw or Repeal                                 │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [], "dkAbstract": null, "docketType": "Rulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2022-06-22T12:28:52Z", "objectId": "0b00006484f08572", "organization": null, "petitionNbr": null, "program": null, "rin": "0991-AC24", "shortTitle": null, "subType": null, "subType2": null, "title": "Securing Updated and Necessary Statutory Evaluations Timely; Proposal to Withdraw or Repeal"}, "id": "CMS-2022-0001", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0001"}, "type": "dockets"}}                                                                                                                                                                                                                                                                                                                                                       │ CMS         │ 2022    │
# │ CMS-2022-0002 │ Nonrulemaking │ 2023-01-18 13:33:18 │ Medicaid Program; Eligibility Changes under the Affordable Care Act of 2010 (CMS–10410)                                     │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [{"label": "Description", "name": "abstract", "tooltip": "Describes an agency's specific regulatory action; equivalents: Abstract, Docket Subject, General Info, Related To, Summary."}], "dkAbstract": "Medicaid Program; Eligibility Changes under the Affordable Care Act of 2010 (CMS\u201310410) ", "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-18T13:33:18Z", "objectId": "0b00006484f11c67", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Medicaid Program; Eligibility Changes under the Affordable Care Act of 2010 (CMS\u201310410)"}, "id": "CMS-2022-0002", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0002"}, "type": "dockets"}}                                                                         │ CMS         │ 2022    │
# │ CMS-2022-0003 │ Nonrulemaking │ 2023-01-18 13:33:31 │ Children’s Health Insurance Program Managed Care and Supporting Regulations (CMS–10554)                                     │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [{"label": "Description", "name": "abstract", "tooltip": "Describes an agency's specific regulatory action; equivalents: Abstract, Docket Subject, General Info, Related To, Summary."}], "dkAbstract": " Children\u2019s Health Insurance Program Managed Care and Supporting Regulations (CMS\u201310554)", "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-18T13:33:31Z", "objectId": "0b00006484f11ca3", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Children\u2019s Health Insurance Program Managed Care and Supporting Regulations (CMS\u201310554)"}, "id": "CMS-2022-0003", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0003"}, "type": "dockets"}}                                                               │ CMS         │ 2022    │
# │ CMS-2022-0004 │ Nonrulemaking │ 2023-01-18 13:31:34 │ Medicaid Accountability – Nursing Facility, Outpatient Hospital and Inpatient Hospital Upper Payment Limits (CMS-10398 #13) │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [{"label": "Description", "name": "abstract", "tooltip": "Describes an agency's specific regulatory action; equivalents: Abstract, Docket Subject, General Info, Related To, Summary."}], "dkAbstract": "Medicaid Accountability \u2013 Nursing Facility, Outpatient Hospital and Inpatient Hospital Upper Payment Limits (CMS-10398 #13) ", "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-18T13:31:34Z", "objectId": "0b00006484f140cd", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Medicaid Accountability \u2013 Nursing Facility, Outpatient Hospital and Inpatient Hospital Upper Payment Limits (CMS-10398 #13)"}, "id": "CMS-2022-0004", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0004"}, "type": "dockets"}} │ CMS         │ 2022    │
# │ CMS-2022-0005 │ Nonrulemaking │ 2023-01-18 13:32:02 │ Medicaid Accountability – Upper Payment Limits for Clinics, Physician Services, ICF/IID, PRTFs, and IMDs  (CMS-10398 #24)   │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [{"label": "Description", "name": "abstract", "tooltip": "Describes an agency's specific regulatory action; equivalents: Abstract, Docket Subject, General Info, Related To, Summary."}], "dkAbstract": "Medicaid Accountability \u2013 Upper Payment Limits for Clinics, Physician Services, ICF/IID, PRTFs, and IMDs (CMS-10398 #24)", "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-18T13:32:02Z", "objectId": "0b00006484f140d1", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Medicaid Accountability \u2013 Upper Payment Limits for Clinics, Physician Services, ICF/IID, PRTFs, and IMDs  (CMS-10398 #24)"}, "id": "CMS-2022-0005", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0005"}, "type": "dockets"}}       │ CMS         │ 2022    │
# │ CMS-2022-0006 │ Nonrulemaking │ 2023-01-18 13:32:16 │ Supplemental Payment Reporting under the Consolidated Appropriations Act, 2021 (CMS-10398 #73)                              │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [{"label": "Description", "name": "abstract", "tooltip": "Describes an agency's specific regulatory action; equivalents: Abstract, Docket Subject, General Info, Related To, Summary."}], "dkAbstract": "Supplemental Payment Reporting under the Consolidated Appropriations Act, 2021 (CMS-10398 #73) ", "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-18T13:32:16Z", "objectId": "0b00006484f14121", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Supplemental Payment Reporting under the Consolidated Appropriations Act, 2021 (CMS-10398 #73)"}, "id": "CMS-2022-0006", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0006"}, "type": "dockets"}}                                                                     │ CMS         │ 2022    │
# │ CMS-2022-0007 │ Nonrulemaking │ 2023-01-18 13:32:28 │ Coverage of Routine Patient Cost for Items & Services in Qualifying Clinical Trials (CMS-10398 #74)                         │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [{"label": "Description", "name": "abstract", "tooltip": "Describes an agency's specific regulatory action; equivalents: Abstract, Docket Subject, General Info, Related To, Summary."}], "dkAbstract": " Coverage of Routine Patient Cost for Items & Services in Qualifying Clinical Trials (CMS-10398 #74)", "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-18T13:32:28Z", "objectId": "0b00006484f14125", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Coverage of Routine Patient Cost for Items & Services in Qualifying Clinical Trials (CMS-10398 #74)"}, "id": "CMS-2022-0007", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0007"}, "type": "dockets"}}                                                           │ CMS         │ 2022    │
# │ CMS-2022-0008 │ Nonrulemaking │ 2023-01-18 13:32:44 │ ARP 1135 State Plan Amendment (CMS-10398 #75)                                                                               │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [{"label": "Description", "name": "abstract", "tooltip": "Describes an agency's specific regulatory action; equivalents: Abstract, Docket Subject, General Info, Related To, Summary."}], "dkAbstract": " ARP 1135 State Plan Amendment (CMS-10398 #75)", "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-18T13:32:44Z", "objectId": "0b00006484f14181", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "ARP 1135 State Plan Amendment (CMS-10398 #75)"}, "id": "CMS-2022-0008", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0008"}, "type": "dockets"}}                                                                                                                                                                       │ CMS         │ 2022    │
# │ CMS-2022-0009 │ Nonrulemaking │ 2022-02-02 13:51:17 │ Requirements Related to Surprise Billing; Part II (CMS-10791)                                                               │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [], "dkAbstract": null, "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2022-02-02T13:51:17Z", "objectId": "0b00006484f15155", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Requirements Related to Surprise Billing; Part II (CMS-10791)"}, "id": "CMS-2022-0009", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0009"}, "type": "dockets"}}                                                                                                                                                                                                                                                                                                                                                                                         │ CMS         │ 2022    │
# │ CMS-2022-0011 │ Nonrulemaking │ 2023-01-27 10:25:41 │ Medicare Registration Application (CMS-855O)                                                                                │ {"data": {"attributes": {"agencyId": "CMS", "category": null, "displayProperties": [], "dkAbstract": null, "docketType": "Nonrulemaking", "effectiveDate": null, "field1": null, "field2": null, "generic": null, "keywords": null, "legacyId": null, "modifyDate": "2023-01-27T10:25:41Z", "objectId": "0b00006484f156f2", "organization": null, "petitionNbr": null, "program": null, "rin": null, "shortTitle": null, "subType": null, "subType2": null, "title": "Medicare Registration Application (CMS-855O)"}, "id": "CMS-2022-0011", "links": {"self": "https://api.regulations.gov/v4/dockets/CMS-2022-0011"}, "type": "dockets"}}                                                                                                                                                                                                                                                                                                                                                                                                          │ CMS         │ 2022    │
# ├───────────────┴───────────────┴─────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴─────────┤
# │ 10 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                7 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Documents

# %%
query = """\
SELECT *
FROM read_parquet(
  'parquet/documents/agency_code=*/year=*/*.parquet',
  hive_partitioning = 1
)
LIMIT 10;
;
"""

conn.query(query)
# Out:
# ┌───────────────┬────────────────────┬──────────┬───────────────┬─────────────────────┬─────────────────────┬─────────────────────┬─────────────────────┬─────────────────────┬────────────┬───────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────┬─────────┐
# │   docket_id   │    document_id     │ category │ document_type │ comment_start_date  │  comment_end_date   │     modify_date     │     posted_date     │    receive_date     │ page_count │ withdrawn │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             raw_json                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ agency_code │  year   │
# │    varchar    │      varchar       │ varchar  │    varchar    │      timestamp      │      timestamp      │      timestamp      │      timestamp      │      timestamp      │   int32    │  boolean  │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             varchar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │   varchar   │ varchar │
# ├───────────────┼────────────────────┼──────────┼───────────────┼─────────────────────┼─────────────────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────┼───────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────┤
# │ CMS-2022-0001 │ CMS-2022-0001-0001 │ NULL     │ Proposed Rule │ 2021-10-29 04:00:00 │ 2021-12-29 04:59:59 │ 2022-01-04 21:57:14 │ 2021-10-29 04:00:00 │ 2021-10-29 04:00:00 │         26 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": "21 CFR Part 6", "city": null, "comment": null, "commentEndDate": "2021-12-29T04:59:59Z", "commentStartDate": "2021-10-29T04:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Proposed Rule", "effectiveDate": "2022-01-01T05:00:00Z", "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0001/content.pdf", "format": "pdf", "size": 464797}, {"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0001/content.htm", "format": "htm", "size": 200359}], "firstName": null, "frDocNum": "2021-23472", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-04T21:57:14Z", "objectId": "0900006484dff981", "ombApproval": null, "openForComment": false, "organization": null, "originalDocumentId": "CMS_FRDOC_0001-3189", "pageCount": 26, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2021-10-29T04:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-10-29T04:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "59906 - 59931", "stateProvinceRegion": null, "subject": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": null, "title": "Securing Updated and Necessary Statutory Evaluations Timely; Proposal to Withdraw or Repeal", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0001-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0001-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0001-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0001-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                                                                                                │ CMS         │ 2022    │
# │ CMS-2022-0002 │ CMS-2022-0002-0001 │ NULL     │ Notice        │ 2022-01-05 05:00:00 │ 2022-03-08 04:59:59 │ 2022-03-09 02:00:51 │ 2022-01-05 05:00:00 │ 2022-01-05 05:00:00 │          2 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-03-08T04:59:59Z", "commentStartDate": "2022-01-05T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": "(CMS\u201310410) Medicaid Program; Eligibility Changes under the Affordable Care Act of 2010", "docketId": "CMS-2022-0002", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0002-0001/content.pdf", "format": "pdf", "size": 200718}, {"fileUrl": "https://downloads.regulations.gov/CMS-2022-0002-0001/content.htm", "format": "htm", "size": 10763}], "firstName": null, "frDocNum": "2021-28527", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-03-09T02:00:51Z", "objectId": "0900006484f0a2c1", "ombApproval": null, "openForComment": false, "organization": null, "originalDocumentId": "CMS_FRDOC_0001-3239", "pageCount": 2, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-01-05T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-05T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "461 - 462", "stateProvinceRegion": null, "subject": "(CMS\u201310410) Medicaid Program; Eligibility Changes under the Affordable Care Act of 2010", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "60 Day Proposed Information Collection", "title": "(CMS\u201310410) Medicaid Program; Eligibility Changes under the Affordable Care Act of 2010", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0002-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0002-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0002-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0002-0001/relationships/attachments"}}}, "type": "documents"}} │ CMS         │ 2022    │
# │ CMS-2022-0003 │ CMS-2022-0003-0001 │ NULL     │ Notice        │ 2022-01-06 05:00:00 │ 2022-03-08 04:59:59 │ 2022-01-06 12:58:26 │ 2022-01-06 05:00:00 │ 2022-01-06 05:00:00 │          0 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-03-08T04:59:59Z", "commentStartDate": "2022-01-06T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": "(CMS\u201310554) Children\u2019s Health Insurance Program Managed Care and Supporting Regulations", "docketId": "CMS-2022-0003", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0003-0001/content.pdf", "format": "pdf", "size": 200718}], "firstName": null, "frDocNum": "2021\u201328527", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-06T12:58:26Z", "objectId": "0900006484f0e600", "ombApproval": null, "openForComment": true, "organization": null, "originalDocumentId": null, "pageCount": 0, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-01-06T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-06T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "461", "stateProvinceRegion": null, "subject": "(CMS\u201310554) Children\u2019s Health Insurance Program Managed Care and Supporting Regulations", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "60 Day Proposed Information Collection", "title": "(CMS\u201310554) Children\u2019s Health Insurance Program Managed Care and Supporting Regulations", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0003-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0003-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0003-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0003-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                                      │ CMS         │ 2022    │
# │ CMS-2022-0004 │ CMS-2022-0004-0001 │ NULL     │ Notice        │ 2022-01-07 05:00:00 │ 2022-01-22 04:59:59 │ 2022-01-22 02:00:28 │ 2022-01-07 05:00:00 │ 2022-01-07 05:00:00 │          3 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-01-22T04:59:59Z", "commentStartDate": "2022-01-07T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0004", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0004-0001/content.pdf", "format": "pdf", "size": 216229}, {"fileUrl": "https://downloads.regulations.gov/CMS-2022-0004-0001/content.htm", "format": "htm", "size": 21488}], "firstName": null, "frDocNum": "2022-00119", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-22T02:00:28Z", "objectId": "0900006484f120e2", "ombApproval": null, "openForComment": false, "organization": null, "originalDocumentId": "CMS_FRDOC_0001-3241", "pageCount": 3, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-01-07T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-07T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "980 - 982", "stateProvinceRegion": null, "subject": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": null, "title": "Agency Information Collection Activities; Proposals, Submissions, and Approvals: Medicaid and Children's Health Insurance Program", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0004-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0004-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0004-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0004-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                                                                                                    │ CMS         │ 2022    │
# │ CMS-2022-0005 │ CMS-2022-0005-0001 │ NULL     │ Notice        │ 2022-01-07 05:00:00 │ 2022-01-22 04:59:59 │ 2022-01-07 19:11:16 │ 2022-01-07 05:00:00 │ 2022-01-07 05:00:00 │          0 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-01-22T04:59:59Z", "commentStartDate": "2022-01-07T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": "(CMS-10398 #24) Medicaid Accountability \u2013 Upper Payment Limits for Clinics, Physician Services, ICF/IID, PRTFs, and IMDs", "docketId": "CMS-2022-0005", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0005-0001/content.pdf", "format": "pdf", "size": 216229}], "firstName": null, "frDocNum": " 2022\u201300119", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-07T19:11:16Z", "objectId": "0900006484f14136", "ombApproval": null, "openForComment": true, "organization": null, "originalDocumentId": null, "pageCount": 0, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-01-07T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-07T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "980", "stateProvinceRegion": null, "subject": "(CMS-10398 #24) Medicaid Accountability \u2013 Upper Payment Limits for Clinics, Physician Services, ICF/IID, PRTFs, and IMDs", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Information Collection Request (ICR)", "title": "(CMS-10398 #24) Medicaid Accountability \u2013 Upper Payment Limits for Clinics, Physician Services, ICF/IID, PRTFs, and IMDs", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0005-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0005-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0005-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0005-0001/relationships/attachments"}}}, "type": "documents"}}                                   │ CMS         │ 2022    │
# │ CMS-2022-0006 │ CMS-2022-0006-0001 │ NULL     │ Notice        │ 2022-01-07 05:00:00 │ 2022-01-22 04:59:59 │ 2022-01-07 19:17:48 │ 2022-01-07 05:00:00 │ 2022-01-07 05:00:00 │          0 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-01-22T04:59:59Z", "commentStartDate": "2022-01-07T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": "(CMS-10398 #73) Supplemental Payment Reporting under the Consolidated Appropriations Act, 2021", "docketId": "CMS-2022-0006", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0006-0001/content.pdf", "format": "pdf", "size": 216229}], "firstName": null, "frDocNum": " 2022\u201300119", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-07T19:17:48Z", "objectId": "0900006484f14139", "ombApproval": null, "openForComment": true, "organization": null, "originalDocumentId": null, "pageCount": 0, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-01-07T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-07T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "980", "stateProvinceRegion": null, "subject": "(CMS-10398 #73) Supplemental Payment Reporting under the Consolidated Appropriations Act, 2021", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Information Collection Request (ICR)", "title": "(CMS-10398 #73) Supplemental Payment Reporting under the Consolidated Appropriations Act, 2021", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0006-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0006-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0006-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0006-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                                                │ CMS         │ 2022    │
# │ CMS-2022-0007 │ CMS-2022-0007-0001 │ NULL     │ Notice        │ 2022-01-07 05:00:00 │ 2022-01-22 04:59:59 │ 2022-01-23 00:19:29 │ 2022-01-07 05:00:00 │ 2022-01-07 05:00:00 │          0 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-01-22T04:59:59Z", "commentStartDate": "2022-01-07T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": "(CMS-10398 #74) Coverage of Routine Patient Cost for Items & Services in Qualifying Clinical Trials", "docketId": "CMS-2022-0007", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0007-0001/content.pdf", "format": "pdf", "size": 216229}], "firstName": null, "frDocNum": " 2022\u201300119", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-23T00:19:29Z", "objectId": "0900006484f1413d", "ombApproval": null, "openForComment": false, "organization": null, "originalDocumentId": null, "pageCount": 0, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-01-07T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-07T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "980", "stateProvinceRegion": null, "subject": "(CMS-10398 #74) Coverage of Routine Patient Cost for Items & Services in Qualifying Clinical Trials", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Information Collection Request (ICR)", "title": "(CMS-10398 #74) Coverage of Routine Patient Cost for Items & Services in Qualifying Clinical Trials", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0007-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0007-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0007-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0007-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                                │ CMS         │ 2022    │
# │ CMS-2022-0008 │ CMS-2022-0008-0001 │ NULL     │ Notice        │ 2022-01-07 05:00:00 │ 2022-01-22 04:59:59 │ 2022-01-07 19:30:52 │ 2022-01-07 05:00:00 │ 2022-01-07 05:00:00 │          0 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-01-22T04:59:59Z", "commentStartDate": "2022-01-07T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": "(CMS-10398 #75) ARP 1135 State Plan Amendment", "docketId": "CMS-2022-0008", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0008-0001/content.pdf", "format": "pdf", "size": 216229}], "firstName": null, "frDocNum": " 2022\u201300119", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-07T19:30:52Z", "objectId": "0900006484f1419d", "ombApproval": null, "openForComment": true, "organization": null, "originalDocumentId": null, "pageCount": 0, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-01-07T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-07T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "980", "stateProvinceRegion": null, "subject": "(CMS-10398 #75) ARP 1135 State Plan Amendment", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Information Collection Request (ICR)", "title": "(CMS-10398 #75) ARP 1135 State Plan Amendment", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0008-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0008-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0008-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0008-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                                                                                                                                                                                                   │ CMS         │ 2022    │
# │ CMS-2022-0009 │ CMS-2022-0009-0001 │ NULL     │ Notice        │ 2022-02-02 05:00:00 │ 2022-03-08 04:59:59 │ 2022-03-09 02:00:43 │ 2022-02-02 05:00:00 │ 2022-01-05 05:00:00 │          2 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2022-03-08T04:59:59Z", "commentStartDate": "2022-02-02T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": "Requirements Related to Surprise Billing; Part II (CMS-10791)", "docketId": "CMS-2022-0009", "documentType": "Notice", "effectiveDate": null, "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0009-0001/content.pdf", "format": "pdf", "size": 200718}, {"fileUrl": "https://downloads.regulations.gov/CMS-2022-0009-0001/content.htm", "format": "htm", "size": 10763}], "firstName": null, "frDocNum": "2021-28527", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-03-09T02:00:43Z", "objectId": "0900006484f142c1", "ombApproval": null, "openForComment": false, "organization": null, "originalDocumentId": null, "pageCount": 2, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2022-02-02T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-05T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "461 - 462", "stateProvinceRegion": null, "subject": "Requirements Related to Surprise Billing; Part II (CMS-10791)", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "60 Day Proposed Information Collection", "title": "Requirements Related to Surprise Billing; Part II (CMS-10791)", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0009-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0009-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0009-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0009-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                               │ CMS         │ 2022    │
# │ CMS-2022-0011 │ CMS-2022-0011-0001 │ NULL     │ Notice        │ 2021-12-30 05:00:00 │ 2021-12-31 04:59:59 │ 2022-01-10 01:07:38 │ 2021-12-30 05:00:00 │ 2021-12-30 05:00:00 │          2 │ false     │ {"data": {"attributes": {"additionalRins": null, "address1": null, "address2": null, "agencyId": "CMS", "allowLateComments": false, "authorDate": null, "authors": null, "category": null, "cfrPart": null, "city": null, "comment": null, "commentEndDate": "2021-12-31T04:59:59Z", "commentStartDate": "2021-12-30T05:00:00Z", "country": null, "displayProperties": [{"label": "Page Count", "name": "pageCount", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0011", "documentType": "Notice", "effectiveDate": "2022-01-31T05:00:00Z", "email": null, "exhibitLocation": null, "exhibitType": null, "fax": null, "field1": null, "field2": null, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0011-0001/content.pdf", "format": "pdf", "size": 190704}, {"fileUrl": "https://downloads.regulations.gov/CMS-2022-0011-0001/content.htm", "format": "htm", "size": 6619}], "firstName": null, "frDocNum": "2021-28358", "frVolNum": null, "govAgency": null, "govAgencyType": null, "implementationDate": null, "lastName": null, "legacyId": null, "media": null, "modifyDate": "2022-01-10T01:07:38Z", "objectId": "0900006484f0049d", "ombApproval": null, "openForComment": false, "organization": null, "originalDocumentId": "CMS_FRDOC_0001-3236", "pageCount": 2, "paperLength": 0, "paperWidth": 0, "phone": null, "postedDate": "2021-12-30T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-30T05:00:00Z", "regWriterInstruction": null, "restrictReason": null, "restrictReasonType": null, "sourceCitation": null, "startEndPage": "74415 - 74416", "stateProvinceRegion": null, "subject": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": null, "title": "Agency Information Collection Activities; Proposals, Submissions, and Approvals", "topics": null, "trackingNbr": null, "withdrawn": false, "zip": null}, "id": "CMS-2022-0011-0001", "links": {"self": "https://api.regulations.gov/v4/documents/CMS-2022-0011-0001"}, "relationships": {"attachments": {"links": {"related": "https://api.regulations.gov/v4/documents/CMS-2022-0011-0001/attachments", "self": "https://api.regulations.gov/v4/documents/CMS-2022-0011-0001/relationships/attachments"}}}, "type": "documents"}}                                                                                                                                                                                                                 │ CMS         │ 2022    │
# ├───────────────┴────────────────────┴──────────┴───────────────┴─────────────────────┴─────────────────────┴─────────────────────┴─────────────────────┴─────────────────────┴────────────┴───────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴─────────┤
# │ 10 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              14 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Comments

# %%
query = """\
SELECT *
FROM read_parquet(
  'parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',
  hive_partitioning = 1
)
LIMIT 10;
;
"""

conn.query(query)
# Out:
# ┌────────────────────┬──────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────────┬─────────────────────┬─────────────────────┬─────────────────────┬────────────────┬────────────────────────────────┬───────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────┬───────────────┬───────┐
# │     comment_id     │           category           │                                                                                                                                                                          comment                                                                                                                                                                           │   document_type   │     modify_date     │     posted_date     │    receive_date     │    subtype     │             title              │ withdrawn │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   raw_json                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ agency_code │   docket_id   │ year  │
# │      varchar       │           varchar            │                                                                                                                                                                          varchar                                                                                                                                                                           │      varchar      │      timestamp      │      timestamp      │      timestamp      │    varchar     │            varchar             │  boolean  │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   varchar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    │   varchar   │    varchar    │ int64 │
# ├────────────────────┼──────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────┼─────────────────────┼─────────────────────┼─────────────────────┼────────────────┼────────────────────────────────┼───────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼───────────────┼───────┤
# │ CMS-2022-0001-0002 │ Consumer Group               │ please see attached                                                                                                                                                                                                                                                                                                                                        │ Public Submission │ 2022-01-21 14:39:16 │ 2022-01-21 05:00:00 │ 2021-12-28 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0002", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0002"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": "Consumer Group", "comment": "please see attached", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484efefa4", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:39:16Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-28T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxq-ef0o-aagc", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484efefa5", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0002/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0002/attachments"}}}}, "included": [{"id": "0900006484efefa5", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484efefa5"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0002/attachment_1.pdf", "format": "pdf", "size": 211467}], "modifyDate": "2022-01-04T16:57:15Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "Medicare Rights Center SUNSET rule repeal comments"}}]}                                                                                                                                                                                                                                                                                                                           │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0001-0003 │ Consumer Group               │ Attached are the comments of Justice in Aging. Thank you for the opportunity to present our views.                                                                                                                                                                                                                                                         │ Public Submission │ 2022-01-21 14:40:25 │ 2022-01-21 05:00:00 │ 2021-12-22 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0003", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0003"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": "Consumer Group", "comment": "Attached are the comments of Justice in Aging. Thank you for the opportunity to present our views.", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484ee200c", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:40:25Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-22T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxi-gfnu-38jr", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484ee7880", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0003/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0003/attachments"}}}}, "included": [{"id": "0900006484ee7880", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484ee7880"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0003/attachment_1.pdf", "format": "pdf", "size": 313264}], "modifyDate": "2022-01-04T16:57:16Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "Sunset repeal Justice in Aging comments 12-28-2021"}}]}                                                                                                                                                                                                                                            │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0001-0004 │ NULL                         │ See attached file.                                                                                                                                                                                                                                                                                                                                         │ Public Submission │ 2022-01-21 14:41:29 │ 2022-01-21 05:00:00 │ 2021-12-28 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0004", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0004"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": null, "comment": "See attached file.", "country": "United States", "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484efef2f", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:41:29Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-28T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": "NC", "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxq-9j08-mq9g", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484efef30", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0004/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0004/attachments"}}}}, "included": [{"id": "0900006484efef30", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484efef30"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0004/attachment_1.pdf", "format": "pdf", "size": 364199}], "modifyDate": "2022-01-04T16:57:17Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "COMMENTS HHS-OS-2020-0012 attachment_1"}}]}                                                                                                                                                                                                                                                                                                                                         │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0001-0005 │ NULL                         │ See attached file(s)                                                                                                                                                                                                                                                                                                                                       │ Public Submission │ 2022-01-21 14:42:27 │ 2022-01-21 05:00:00 │ 2021-12-27 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0005", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0005"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": null, "comment": "See attached file(s)", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484efde16", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:42:27Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-27T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxp-3un5-swvy", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484efde17", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0005/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0005/attachments"}}}}, "included": [{"id": "0900006484efde17", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484efde17"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0005/attachment_1.pdf", "format": "pdf", "size": 238122}], "modifyDate": "2022-01-04T16:57:18Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "NCLR comments on SUNSET Rule repeal (RIN 0991-AC24)"}}]}                                                                                                                                                                                                                                                                                                                                     │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0001-0006 │ NULL                         │ See attached file                                                                                                                                                                                                                                                                                                                                          │ Public Submission │ 2022-01-21 14:43:25 │ 2022-01-21 05:00:00 │ 2021-12-23 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0006", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0006"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": null, "comment": "See attached file", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484ee81fe", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:43:25Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-23T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxj-8ji8-ggxl", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484ee81ff", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0006/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0006/attachments"}}}}, "included": [{"id": "0900006484ee81ff", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484ee81ff"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0006/attachment_1.pdf", "format": "pdf", "size": 126445}], "modifyDate": "2022-01-04T16:57:18Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "TTAG Letter to HHS in Support of SUNSET Rule Repeal"}}]}                                                                                                                                                                                                                                                                                                                                        │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0001-0007 │ Association - Other          │ United Fresh Produce Association supports the proposal by the Department of Health and Human Services to withdraw or repeal a final rule entitled ``Securing Updated and Necessary Statutory Evaluations Timely&#39;&#39; (SUNSET final rule), published in the Federal Register of January 19, 2021. Please see attached file for additional information. │ Public Submission │ 2022-01-21 14:44:23 │ 2022-01-21 05:00:00 │ 2021-12-27 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0007", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0007"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": "Association - Other", "comment": "United Fresh Produce Association supports the proposal by the Department of Health and Human Services to withdraw or repeal a final rule entitled ``Securing Updated and Necessary Statutory Evaluations Timely&#39;&#39; (SUNSET final rule), published in the Federal Register of January 19, 2021. Please see attached file for additional information.", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484efdd4b", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:44:23Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-27T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxo-wh4s-gyul", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484efdd4c", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0007/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0007/attachments"}}}}, "included": [{"id": "0900006484efdd4c", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484efdd4c"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0007/attachment_1.pdf", "format": "pdf", "size": 98324}], "modifyDate": "2022-01-04T16:57:19Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "2021 United Fresh SUNSET comments"}}]} │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0001-0008 │ NULL                         │ Please see attached                                                                                                                                                                                                                                                                                                                                        │ Public Submission │ 2022-01-21 14:47:20 │ 2022-01-21 05:00:00 │ 2021-12-28 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0008", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0008"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": null, "comment": "Please see attached", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484eff02e", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:47:20Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-28T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxq-ixfn-qi23", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484eff02f", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0008/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0008/attachments"}}}}, "included": [{"id": "0900006484eff02f", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484eff02f"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0008/attachment_1.pdf", "format": "pdf", "size": 26346}], "modifyDate": "2022-01-04T16:57:21Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "SUNSET Repeal-PTNPA Comments"}}]}                                                                                                                                                                                                                                                                                                                                                              │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0001-0009 │ Association - Other          │ Please find attached comments from the North American Millers&rsquo; Association (NAMA)  on the Department of Health and Human Services&rsquo; Proposed Rule &ldquo;Securing Updated and Necessary Statutory Evaluations Timely; Proposal to Withdraw or Repeal. (Docket No. HHS-OS-2020-0012)                                                             │ Public Submission │ 2022-01-21 14:48:18 │ 2022-01-21 05:00:00 │ 2021-12-28 05:00:00 │ Public Comment │ Comment on CMS_FRDOC_0001-3189 │ false     │ {"data": {"id": "CMS-2022-0001-0009", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0009"}, "attributes": {"commentOn": "0900006484dff981", "commentOnDocumentId": "CMS-2022-0001-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": "Association - Other", "comment": "Please find attached comments from the North American Millers&rsquo; Association (NAMA)  on the Department of Health and Human Services&rsquo; Proposed Rule &ldquo;Securing Updated and Necessary Statutory Evaluations Timely; Proposal to Withdraw or Repeal. (Docket No. HHS-OS-2020-0012)", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0001", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484eff035", "lastName": null, "legacyId": null, "modifyDate": "2022-01-21T14:48:18Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-01-21T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2021-12-28T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS_FRDOC_0001-3189", "trackingNbr": "kxq-j7qt-1c1f", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [{"id": "0900006484eff036", "type": "attachments"}], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0009/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0001-0009/attachments"}}}}, "included": [{"id": "0900006484eff036", "type": "attachments", "links": {"self": "https://api.regulations.gov/v4/attachments/0900006484eff036"}, "attributes": {"agencyNote": null, "authors": null, "docAbstract": null, "docOrder": 1, "fileFormats": [{"fileUrl": "https://downloads.regulations.gov/CMS-2022-0001-0009/attachment_1.pdf", "format": "pdf", "size": 100040}], "modifyDate": "2022-01-04T16:57:21Z", "publication": null, "restrictReason": null, "restrictReasonType": null, "title": "NAMA Comments on HHS Proposed SUNSET Rule - FINAL - 12.28.2021"}}]}                               │ CMS         │ CMS-2022-0001 │  2022 │
# │ CMS-2022-0002-0002 │ Health Care Industry - PI015 │ Eligibility changes are needed                                                                                                                                                                                                                                                                                                                             │ Public Submission │ 2022-03-08 12:06:59 │ 2022-03-08 05:00:00 │ 2022-01-30 05:00:00 │ Public Comment │ Comment on CMS-2022-0002-0001  │ false     │ {"data": {"id": "CMS-2022-0002-0002", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0002-0002"}, "attributes": {"commentOn": "0900006484f0a2c1", "commentOnDocumentId": "CMS-2022-0002-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": "Health Care Industry - PI015", "comment": "Eligibility changes are needed", "country": null, "displayProperties": [{"name": "pageCount", "label": "Page Count", "tooltip": "Number of pages In the content file"}], "docAbstract": null, "docketId": "CMS-2022-0002", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": "Anonymous", "govAgency": null, "govAgencyType": null, "objectId": "0900006484f477c2", "lastName": "Anonymous", "legacyId": null, "modifyDate": "2022-03-08T12:06:59Z", "organization": null, "originalDocumentId": null, "pageCount": 1, "phone": null, "postedDate": "2022-03-08T05:00:00Z", "postmarkDate": null, "reasonWithdrawn": null, "receiveDate": "2022-01-30T05:00:00Z", "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": "Public Comment", "title": "Comment on CMS-2022-0002-0001", "trackingNbr": "kz2-110z-ecgj", "withdrawn": false, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0002-0002/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0002-0002/attachments"}}}}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ CMS         │ CMS-2022-0002 │  2022 │
# │ CMS-2022-0004-0002 │ NULL                         │ NULL                                                                                                                                                                                                                                                                                                                                                       │ Public Submission │ 2022-01-22 12:45:37 │ 2022-01-21 00:00:00 │ NULL                │ NULL           │ Comment on CMS-2022-0004-0001  │ true      │ {"data": {"id": "CMS-2022-0004-0002", "type": "comments", "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0004-0002"}, "attributes": {"commentOn": "0900006484f120e2", "commentOnDocumentId": "CMS-2022-0004-0001", "duplicateComments": 0, "address1": null, "address2": null, "agencyId": "CMS", "city": null, "category": null, "comment": null, "country": null, "displayProperties": null, "docAbstract": null, "docketId": "CMS-2022-0004", "documentType": "Public Submission", "email": null, "fax": null, "field1": null, "field2": null, "fileFormats": null, "firstName": null, "govAgency": null, "govAgencyType": null, "objectId": "0900006484f2e950", "lastName": null, "legacyId": null, "modifyDate": "2022-01-22T12:45:37Z", "organization": null, "originalDocumentId": null, "pageCount": 0, "phone": null, "postedDate": "2022-01-21T00:00:00Z", "postmarkDate": null, "reasonWithdrawn": "Comment was submitted to the wrong docket. Moved comment to the correct docket.", "receiveDate": null, "restrictReason": null, "restrictReasonType": null, "stateProvinceRegion": null, "submitterRep": null, "submitterRepAddress": null, "submitterRepCityState": null, "subtype": null, "title": "Comment on CMS-2022-0004-0001", "trackingNbr": null, "withdrawn": true, "zip": null, "openForComment": false}, "relationships": {"attachments": {"data": [], "links": {"self": "https://api.regulations.gov/v4/comments/CMS-2022-0004-0002/relationships/attachments", "related": "https://api.regulations.gov/v4/comments/CMS-2022-0004-0002/attachments"}}}}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ CMS         │ CMS-2022-0004 │  2022 │
# ├────────────────────┴──────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────────────┴─────────────────────┴─────────────────────┴─────────────────────┴────────────────┴────────────────────────────────┴───────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴───────────────┴───────┤
# │ 10 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      14 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Querying from S3

# %%
query = """\
CREATE OR REPLACE SECRET secret (
    TYPE s3,
    PROVIDER credential_chain,
    PROFILE 'civictechdc'
);
"""
conn.query(query)
# Out:
# ┌─────────┐
# │ Success │
# │ boolean │
# ├─────────┤
# │ true    │
# └─────────┘

# %%
query = """\
SELECT COUNT(*)
FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',
        hive_partitioning = 1
    )
;
"""

conn.query(query)
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       479462 │
# └──────────────┘

# %%
# Example power of SQL

# Query comments for records where the `comment` field contains the word "supports"

query = """\
SELECT docket_id, comment_id, *
FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',
        hive_partitioning = 1
    )
WHERE LOWER(comment) LIKE '%supports%'
LIMIT 10;
"""

conn.query(query)
# Out:
# ┌───────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │   docket_id   │     comment_id     │     comment_id     │       category       │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      comment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# │    varchar    │      varchar       │      varchar       │       varchar        │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      varchar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# ├───────────────┼────────────────────┼────────────────────┼──────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ CMS-2022-0001 │ CMS-2022-0001-0007 │ CMS-2022-0001-0007 │ Association - Other  │ United Fresh Produce Association supports the proposal by the Department of Health and Human Services to withdraw or repeal a final rule entitled ``Securing Updated and Necessary Statutory Evaluations Timely&#39;&#39; (SUNSET final rule), published in the Federal Register of January 19, 2021. Please see attached file for additional information.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# │ CMS-2022-0012 │ CMS-2022-0012-0187 │ CMS-2022-0012-0187 │ NULL                 │ I am writing this comment on behalf of independent pharmacists/pharmacies in Kentucky; members of KIPA, Kentucky Independent Pharmacy Alliance.  Our organization is in full support of proposed rule CMS-4192-P, Medicare program.  DIR fees here in Kentucky have grown by over 107,000%.  This is unsustainable for both pharmacies and patients. The price concession arrangements developed between pharmacies and the PBMs for plan sponsors never offered any opportunity for negotiations by the pharmacy. Contracts are &quot;offered&quot; with a take it or leave it proposal we had to sign in order to service our patients.  Value based contracting by the trade group for the PBMs does not improve quality and safety for Medicare beneficiaries.  Pharmacists have dedicated their lives to the health and welfare of their patients.  Yet PBMs claw back hundreds of thousands of dollars usually months after we have filled the original prescription, as well as refills.  Do our patients get refunds after the DIR fee is taken from us? NO.  So where do these DIR fees actually go?  To the PBMs and their plan sponsors.  KIPA supports proposed rule CMS-4192-P because it would lower out-of-pocket costs for our Medicare patients.  This rule would also open the black box of DIR fees and expose the financial uncertainty of running a pharmacy under these circumstances.  And the performance measures used to evaluate our pharmacies are non-uniform, shady and only intended to increase the claw backs.  Quite often, theses claw backs, when disclosed MONTHS later show that pharmacies have filled the prescription below their cost.  Our members have reported DIR fees from 40k to 100k for 2021. Multiply those numbers by about 500 pharmacies in Kentucky, and we arrive at $50,000,000.  Where has the money gone?  The members of KIPA wholeheartedly support the proposed rule CMS-4192-P.  As health-care providers crucial to the health of all our patients and business owners, we need to know at the point of sale the final price we are paid for filling those prescriptions.  Opening the black box of DIR will show us our reimbursement at the point of sale.  It will keep independent pharmacies viable and able to serve our Medicare patients.  Any form of business of any kind, has not only the right but the necessity to know exactly the amount of profit or loss at the point of transaction.  How can anyone run a business blinded and handicapped.  And why would anyone want a practice that serves those in need to be worried, stressed, or distracted instead of able to help.  Even the food industry is supporting government efforts to lower drug costs.  When an outside entity with no skin in the game notices the problem,  it must be a problem.  Respectfully,  Katherine L Chase, RPh.  Corner Pharmacy, Lexington, Ky                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# │ CMS-2022-0012 │ CMS-2022-0012-0499 │ CMS-2022-0012-0499 │ NULL                 │ The Honorable Chiquita Brooks-LaSure<br/>Administrator<br/>Centers for Medicare &amp;amp; Medicaid Services<br/>7500 Security Boulevard<br/>Baltimore, MD 21244<br/><br/>RE: Medicare Program; Contract Year 2023 Policy and Technical Changes to the Medicare <br/>Advantage and Medicare Prescription Drug Benefit Programs (CMS-4192-P)<br/><br/>Dear Administrator Brooks-LaSure:<br/><br/>Thank you for considering this issue.  I am a small pharmacy owner and will keep this brief. PBMs are the reason American patients pay more for medications than all other patients in the world.  PBMs are the gate keepers of prescriptions and the Medicare Part D system is set up to to make them rich at the expense of our patients.  <br/><br/>The big picture is that the entire system supports higher prices to patients and our government as the insurer.  The higher the price paid, the higher the percentage for the PBM to collect as a variable and enormous DIR fee forced on our pharmacies.  <br/><br/>To make matters worse, PBMs all own their own mail order pharmacies.  DIR fees putting pharmacies out of business, means more money for their own pharmacy&#39;s monopoly.  <br/><br/>You can make an huge difference by making PBMs accountable.  Unfortunately, the PBMs business model has been extremely successful at gaming the system.  They will be ten steps ahead of any changes you make.  These billion dollar companies must be held accountable.  They have contingency plan upon contingency plan in place to brush off any slap on the wrist.  We have seen it continually in the private sector.  <br/><br/>Enforcement and substantial punitive damages will only be a start.  Contracts should be cancelled when they inevitably move on to the next illegal scheme.<br/><br/>Thank you for you time.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# │ CMS-2022-0012 │ CMS-2022-0012-3005 │ CMS-2022-0012-3005 │ State Government -…  │ PLEASE do not force Massachusetts to take a step backwards by converting its One Care program for Dual Eligible people from a demonstration program to a D-SNP!<br/><br/>People with disabilities in Massachusetts have been able to maintain their independence and One Care has been able to provide integrated and cost effective care for a vulnerable population. <br/><br/>One size definitely does not fit all. As written, &quot;Dual Special Needs Plans (D-SNPs) lack flexibility and are not as focused on independence as the plan we have now. This kind of change poses several significant consequences for people with disabilities currently enrolled in One Care.  Issues include the following:<br/><br/>1. Possible elimination of the Implementation Council, which provides crucial oversight and accountability to ensure plans are serving members.<br/>2. Removal of federal funding for My Ombudsman to serve One Care members<br/>3. Weaker network adequacy standards that could make accessible medical care harder to come by.<br/>4. Less flexibility in funding, which could lead to specialized supports and equipment being even harder to get. As it is, lack of access to appropriate durable medical equipment causes preventable, expensive, and often deadly complications.<br/>5. Loss of integration between Medicare and Medicaid, leading to enrollment problems.<br/>6. One-size-fits-all quality standards that could financially incentivize plans to drop their sickest and most disabled members.<br/><br/>Rather than defanging a relatively successful model, I hope that CMS will choose to replicate it.<br/><br/>Thank you,<br/>Susan Biener Bergman, M.D.<br/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# │ CMS-2022-0012 │ CMS-2022-0012-3489 │ CMS-2022-0012-3489 │ Other - OT001        │ These comments address the recently published Centers for Medicare and Medicaid Services (CMS) Contract Year 2023 Medicare Advantage and Part D proposed rule. They are submitted by the Massachusetts Housing and Shelter Alliance (MHSA).  The Massachusetts Housing and Shelter Alliance&rsquo;s mission is to end homelessness through advocacy, collaboration, education, housing and the implementation of outcome-based programs. MHSA is dedicated to innovative solutions that reduce public reliance on emergency resources. MHSA&rsquo;s whole history is connected to the ending of the homelessness of unaccompanied adults. MHSA has been incredibly successful in developing innovative housing approaches to housing disabled persons experiencing long term and chronic homelessness. This is all accomplished through a collaborative of nearly 100 statewide participating member agencies. A key part of our success has been in initiating innovative utilization of Medicaid and Medicare in addressing the social determinants of health, especially housing, in order to achieve better and less costly quality of care for enrollees of both Medicaid and Medicare for dually-eligible persons experiencing homelessness.<br/> <br/>We oppose the proposed transition of Medicare-Medicaid Plans (MMPs) to Dual-Eligible Special Needs Plans (D-SNPs) authority. We do so because to do so is to limit innovation in the area of addressing the social determinants of health so critical both to the quality and cost of services funded under both Medicaid and Medicare. In short, the proposed rule essentially eliminates the meaningful incentives for more states to offer integrated benefits and, as a result, innovation in care. While implementation of D-SNPs may lead some states to some higher level of integration of care, in Massachusetts it will result in a movement away from innovation in achieving true integration of care.<br/><br/>Why? As Allison Rizer, wrote in ATI Advisory &ldquo;misaligned financing is the single biggest contributing factor to fragmented experiences.&rdquo; (2/16/22). D-SNPs, while perhaps giving some states a basic framework for integrating plans of providers, they do not distribute cost and risk in a manner that will incentivize state investment in proven strategies shown to both improve quality of care and reduce overall cost. The resultant cost shifting that results from this division does not lead to authentic integration of care.  Nor does it incentivize states to invest in such social determinants of health as housing, nutrition and transportation. These regulations do not provide meaningful incentives for states to move toward more integrated care. In fact, their overriding of the most innovative part of the Financial Alignment Initiative (FAI) demonstration project represent a step away from the meaning and purpose of the Affordable Care Act.<br/> <br/>In Massachusetts, this has deep significance for us serving disabled persons experiencing homelessness in housing. The MMP Dual Eligibility Demonstration One Care represented a new level in integrated care that invested in tenant-based services modelled on the CSP program. This has proven to be very effective in significantly changing utilization patterns in medical care, especially hospitalization. It is hard to imagine this ever having occurred without the unique responsibility of both Medicaid and Medicare for the risk associated with this innovation. Why should a state invest significant amounts of money in housing supports when the benefit of such investment accrues only to Medicare? The D-SNPs lack the same cost/risk sharing model that makes the State and Federal systems partners in achieving the common good of authentic integrated care.<br/><br/>We strongly encourage the adoption and inclusion of MMP models for states willing to invest and develop true integrated systems of care.                                   ...
# │ CMS-2022-0012 │ CMS-2022-0012-3601 │ CMS-2022-0012-3601 │ Health Plan or Ass…  │ The Hogg Foundation for Mental Health supports standardizing housing, food insecurity, and transportation questions as part of the health risk assessment for Medicare Advantage Special Needs Plans.  This information is extremely important to have a holistic understanding of individuals overall health and well-being.  It provides critical information that directly and indirectly impacts health and mental health.  Answers to these questions help capture social determinant information that is not only useful clinically, but also the data can be curated for evaluation on the population level.  This type of information and analysis then allows plans to provide and develop resources that ensures quality of care and the best health care outcomes possible. <br/><br/>The above comment relates to Section 1859(f)(5) of the Social Security Act.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# │ CMS-2022-0012 │ CMS-2022-0012-3887 │ CMS-2022-0012-3887 │ NULL                 │ RE: Medicare Program; Contract Year 2023 Policy and Technical Changes to the Medicare <br/>Advantage and Medicare Prescription Drug Benefit Programs (CMS-4192-P)<br/><br/>Dear Administrator Brooks-LaSure:<br/><br/>The following comments provide a 30-year practicing Pharmacists perspective regarding direct and indirect remuneration (DIR) fees as related to Medicare prescription drug program.  My experience in Hospital Pharmacy, as well as, both Retail Big-Chain Pharmacy and Retail Independent owned Pharmacy has allowed me to develop an understanding and perspective of the comparative impacts and business strategies associated with how these organizations work in concert to provide patient service, as well as, compete.  Contrary to propaganda from big chain lobbyist groups, Independent Pharmacy,  by far provides better customer service, and from my experience, patients prefer the personalized care offered through an Independent Pharmacy.  These smaller Independent Pharmacy operations are at a great disadvantage because they typically do not have 340B pricing advantages associated with Hospital Pharmacy and they do not own insurance companies or PBMs that steer customers to their mail order or chain Pharmacy.  The impact of DIR fees on these Independent Pharmacies is profound.  We have witnessed a 100,000% increase over the last 10 years, just last year alone, we witnessed a 54% increase in DIR fees at our Pharmacy.  Recent fee reports for 2022, put us on track for another 50% increase.  It is common for Independent Pharmacies to pay more in DIR fees than net profit.  This burden detours the opportunity to improve services to the communities in which we provide critical support. There is something direly wrong with the DIR program, as logic would indicate the fees should track with drug prices, but there is an obvious disconnect with these fees jumping 100,000% in a ten-year time frame, and a further obvious disconnect with fee increases of +50% for 2021 and 2022; projected.   It is as if this system has strategically been weaponized or manipulated to drive Independent Pharmacy out of business.  It is incontestable that this has led to many Pharmacy closings and reduced service across the country.   Considering the original intent of the Part D DIR program and what it was allowed to grow into relative to PBM abuse, and considering it has taken over 20 years to obtain judgment on ERISA law from the Supreme Court to correct the Part D program, it is very concerning that the new regulatory language not be open to the same abuse we have witnessed over the last 20 years.  Two of the most pronounced indicators that the prescription drug business is of questionable integrity are:  1) the use of contract gag orders relative to cash price versus insurance co-pay, and 2) the black-box, non-transparent DIR fee claw backs from PBMs.   As an Independent Pharmacy we are subject to insurance company gag orders.  If we provide the patient with information on a lower cash price versus their co-pay, we are threatened with contract termination by the insurance company. Relative to the second point, the DIR fees are purposely designed as non-transparent, black-box group fees, so we can not evaluate individual DIR claw backs to determine if we have recourse relative to below cost pricing laws (predatory pricing).  <br/>I suggest CMS make definitive changes to simplify the program in an effort to counter manipulation of the system.  One way to do this would be to shift all fees to the point of sale.  In other words, all the PBM negotiated rebates and fees become transparent and are addressed at the point of sale.  This would be better for CMS, the consumer, and consistent with good accounting principles. Most importantly, this would be consistent with how most businesses operate in a democratic society that supports fair competition and free trade.<br/>Thank you for con ...
# ...
# ├───────────────┴────────────────────┴────────────────────┴──────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ 10 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...

# %%
# Count whether `comment` field contains the word "supports"

query = """\
WITH comments AS (
    SELECT
        *,
        LOWER(comment) LIKE '%supports%' AS contains_supports
    FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',
        hive_partitioning = 1
    )
)
SELECT comments.contains_supports, COUNT(*)
FROM comments
GROUP BY comments.contains_supports
"""

conn.query(query)
# Out:
# ┌───────────────────┬──────────────┐
# │ contains_supports │ count_star() │
# │      boolean      │    int64     │
# ├───────────────────┼──────────────┤
# │ true              │         5101 │
# │ NULL              │         2404 │
# │ false             │       471957 │
# └───────────────────┴──────────────┘

# %%
# Example complex query with joins

# Count comments by Docket Type and whether the comment text contains the word "supports"

query = """\
WITH dockets AS (
    SELECT *
    FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/dockets/agency_code=*/year=*/*.parquet',
        hive_partitioning = 1
    )
),
comments AS (
    SELECT
        *,
        LOWER(comment) LIKE '%supports%' AS contains_supports
    FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',
        hive_partitioning = 1
    )
)
SELECT dockets.agency_code, dockets.docket_type, comments.contains_supports, COUNT(*)
FROM comments
JOIN dockets ON comments.docket_id = dockets.docket_id
GROUP BY dockets.agency_code, docket_type, comments.contains_supports
ORDER BY dockets.agency_code, docket_type, comments.contains_supports
"""

conn.query(query)
# Out:
# ┌─────────────┬───────────────┬───────────────────┬──────────────┐
# │ agency_code │  docket_type  │ contains_supports │ count_star() │
# │   varchar   │    varchar    │      boolean      │    int64     │
# ├─────────────┼───────────────┼───────────────────┼──────────────┤
# │ CMS         │ Nonrulemaking │ false             │       130021 │
# │ CMS         │ Nonrulemaking │ true              │         4562 │
# │ CMS         │ Nonrulemaking │ NULL              │           16 │
# │ CMS         │ Rulemaking    │ false             │      5225340 │
# │ CMS         │ Rulemaking    │ true              │        41243 │
# │ CMS         │ Rulemaking    │ NULL              │          141 │
# │ DEA         │ Nonrulemaking │ false             │         1770 │
# │ DEA         │ Nonrulemaking │ true              │            1 │
# │ DEA         │ Rulemaking    │ false             │      3281337 │
# │ DEA         │ Rulemaking    │ true              │        86601 │
# │ DEA         │ Rulemaking    │ NULL              │          399 │
# │ FTA         │ Nonrulemaking │ false             │        16860 │
# │ FTA         │ Nonrulemaking │ true              │          430 │
# │ FTA         │ Nonrulemaking │ NULL              │         1350 │
# │ FTA         │ Rulemaking    │ false             │       177736 │
# │ FTA         │ Rulemaking    │ true              │          107 │
# │ FTA         │ Rulemaking    │ NULL              │         1181 │
# ├─────────────┴───────────────┴───────────────────┴──────────────┤
# │ 17 rows                                              4 columns │
# └────────────────────────────────────────────────────────────────┘

# %%
# Get the mean difference between comments.posted_date and comments.receive_date
# But only where the docket type is 'Rulemaking' and the comment contains the word "supports"

query = """\
WITH comments AS (
    SELECT
        *,
        LOWER(comment) LIKE '%supports%' AS contains_supports
    FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',
        hive_partitioning = 1
    )
),
dockets AS (
    SELECT *
    FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/dockets/agency_code=*/year=*/*.parquet',
        hive_partitioning = 1
    )
)
SELECT mean(comments.posted_date - comments.receive_date)
FROM comments
JOIN dockets ON comments.docket_id = dockets.docket_id
WHERE dockets.agency_code = 'CMS'
    AND dockets.docket_type = 'Rulemaking'
    AND comments.contains_supports = TRUE
GROUP BY comments.contains_supports
"""

conn.query(query)
# Out:
# ┌──────────────────────────────────────────────────────────┐
# │ mean(("comments".posted_date - "comments".receive_date)) │
# │                         interval                         │
# ├──────────────────────────────────────────────────────────┤
# │ 4 days 21:56:38.373862                                   │
# └──────────────────────────────────────────────────────────┘

# %%
query = """\
EXPLAIN (ANALYZE, FORMAT TEXT)

WITH comments AS (
    SELECT
        *,
        LOWER(comment) LIKE '%supports%' AS contains_supports
    FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',
        hive_partitioning = 1
    )
),
dockets AS (
    SELECT *
    FROM read_parquet(
        's3://jay-mirrulations-demo/mirrulations_parquet/dockets/agency_code=*/year=*/*.parquet',
        hive_partitioning = 1
    )
)
SELECT mean(comments.posted_date - comments.receive_date)
FROM comments
JOIN dockets ON comments.docket_id = dockets.docket_id
WHERE dockets.agency_code = 'CMS'
    AND dockets.docket_type = 'Rulemaking'
    AND comments.contains_supports = TRUE
GROUP BY comments.contains_supports
"""

print(conn.execute(query).fetchone()[1])
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# EXPLAIN (ANALYZE, FORMAT TEXT)  WITH comments AS (     SELECT         *,         LOWER(comment) LIKE '%supports%' AS contains_supports     FROM read_parquet(         's3://jay-mirrulations-demo/mirrulations_parquet/comments/agency_code=*/year=*/docket_id=*/*.parquet',         hive_partitioning = 1     ) ), dockets AS (     SELECT *     FROM read_parquet(         's3://jay-mirrulations-demo/mirrulations_parquet/dockets/agency_code=*/year=*/*.parquet',         hive_partitioning = 1     ) ) SELECT mean(comments.posted_date - comments.receive_date) FROM comments JOIN dockets ON comments.docket_id = dockets.docket_id WHERE dockets.agency_code = 'CMS'     AND dockets.docket_type = 'Rulemaking'     AND comments.contains_supports = TRUE GROUP BY comments.contains_supports
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││         HTTPFS HTTP Stats         ││
# ││                                   ││
# ││            in: 0 bytes            ││
# ││            out: 0 bytes           ││
# ││              #HEAD: 0             ││
# ││              #GET: 0              ││
# ││              #PUT: 0              ││
# ││              #POST: 0             ││
# ││             #DELETE: 0            ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.372s              ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │      EXPLAIN_ANALYZE      │
# │    ────────────────────   │
# │           0 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │    mean((posted_date -    │
# │       receive_date))      │
# │                           │
# │           1 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │    Aggregates: mean(#1)   │
# │                           │
# │           1 Rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │     contains_supports     │
# │       (posted_date -      │
# │        receive_date)      │
# │                           │
# │         41243 Rows        │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         HASH_JOIN         │
# │    ────────────────────   │
# │      Join Type: INNER     │
# │                           │
# │        Conditions:        ├──────────────┐
# │   docket_id = docket_id   │              │
# │                           │              │
# │         41243 Rows        │              │
# │          (0.01s)          │              │
# └─────────────┬─────────────┘              │
# ┌─────────────┴─────────────┐┌─────────────┴─────────────┐
# │         PROJECTION        ││         TABLE_SCAN        │
# │    ────────────────────   ││    ────────────────────   │
# │        posted_date        ││         Function:         │
# │        receive_date       ││        READ_PARQUET       │
# │         docket_id         ││                           │
# │     contains_supports     ││        Projections:       │
# │                           ││         docket_id         │
# │                           ││                           │
# │                           ││          Filters:         │
# │                           ││  docket_type='Rulemaking' │
# │                           ││                           │
# │                           ││       File Filters:       │
# │                           ││   (agency_code = 'CMS')   │
# │                           ││                           │
# │                           ││    Scanning Files: 4/46   │
# │                           ││    Total Files Read: 4    │
# │                           ││                           │
# │         2520 Rows         ││          680 Rows         │
# │          (0.01s)          ││          (0.00s)          │
# └─────────────┬─────────────┘└───────────────────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │         Function:         │
# │        READ_PARQUET       │
# │                           │
# │        Projections:       │
# │          comment          │
# │        posted_date        │
# │        receive_date       │
# │         docket_id         │
# │                           │
# │          Filters:         │
# │ (contains(lower(comment), │
# │    'supports') = true)    │
# │                           │
# │   Total Files Read: 280   │
# │                           │
# │         2520 Rows         │
# │          (0.80s)          │
# └───────────────────────────┘

# %%
# !find "parquet/comments" -type f -name '*.parquet' | wc -l
# Out:
# 680
